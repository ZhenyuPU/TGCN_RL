# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Model import MILP_Model, MILP_Solver
from Utils.prediction_utils import Args

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 先预测未来C个时间段，然后优化完成后得到第C时刻的状态，再优化下一个C，直到整个时间段结束。如果预测整个时间段，那么在预测很精确的基础上优化之后这段时间按理说应该回报最大，但是预测很难精确；当一段一段预测，精度会变高，但是总的优化结果不一定更好，因为目标比较短视。这里有一个Trade-off，需要仔细研究

# %%
args = Args()

Solver = MILP_Solver.Solver(pred_method='TGCN_me')

# %%
# # 开启预测训练
# _ = Solver.MPC_prediction(result_train_file='result/prediction_result/train', result_forecast_file=None, train=True, args=args)

# %%
# 开始执行MPC
res = Solver.implement_MPC(result_train_file='result/prediction_result/train', result_forecast_file=None, start_day=1, end_day=10, pred_horizon=24, horizon=24)
